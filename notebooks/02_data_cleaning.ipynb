# %% [markdown]
# cleaning

# %%
df_long = df_long.dropna()
df_long["year"] = df_long["year"].astype(int)

# %%
spain = df_long[df_long["Country Name"] == "Spain"]
spain.head()
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  year  \
# 70          Spain          ESP  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 336         Spain          ESP  GDP (current US$)  NY.GDP.MKTP.CD  1961
# 602         Spain          ESP  GDP (current US$)  NY.GDP.MKTP.CD  1962
# 868         Spain          ESP  GDP (current US$)  NY.GDP.MKTP.CD  1963
# 1134        Spain          ESP  GDP (current US$)  NY.GDP.MKTP.CD  1964
#
#                GDP
# 70    1.242451e+10
# 336   1.423813e+10
# 602   1.660963e+10
# 868   1.963171e+10
# 1134  2.196688e+10

# %%
plt.plot(spain["year"], spain["GDP"])
plt.title("Spain GDP over time")
plt.xlabel("Year")
plt.ylabel("GDP")
plt.show()
